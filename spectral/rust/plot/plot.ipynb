# %%
import plotly.express as px
import pandas as pd


df = pd.read_csv('output.txt')
# print(df)

fig = px.line(df,
                 x="x",
                 y="u",
            animation_frame="t"
)
fig.show()
